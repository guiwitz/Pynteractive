# %%
import numpy as np
import matplotlib.pyplot as plt
from compcolor import Combcol
import skimage.io
from IPython.display import HTML

# %%
cc = Combcol()

# %%
image = skimage.io.imread('Data/mitosis.tif')
im_proj = np.mean(image,axis = 1)

# %%
cc.interactive_colors(im_proj)

# %%
cc.movie_histogram(im_proj, movie_name = 'myvideo2.mp4')

# %%
# %%HTML
# <div align="middle">
# <video width="80%" controls>
#       <source src="myvideo2.mp4" type="video/mp4">
# </video></div>
# Out:
# <div align="middle">
# <video width="80%" controls>
#       <source src="myvideo2.mp4" type="video/mp4">
# </video></div>
